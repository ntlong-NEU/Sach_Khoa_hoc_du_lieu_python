# %% [markdown]
# ## Lịch sử hình thành môn học
#
# - **Tên môn học ban đầu**: *Khoa học dữ liệu trong Kinh tế và Kinh doanh* (tiếng Việt, mã TOKT1138)
# - **Chương trình Actuary** (Toán Kinh tế): môn học với tên gọi *Predictive Analytics*
# - Dạy cho SV Ngành Toán Kinh tế (kỳ 6–7)
# - Yêu cầu tiên quyết:
#     - Giải tích 1
#     - Giải tích 2
#     - Đại số
#     - Lý thuyết xác suất
#     - Thống kê Toán
#     - Kinh tế lượng
#     - Lập trình C
#     - Lập trình R
#
#
# ## Chủ trương từ Đại học
#
# **Theo Kế hoạch số 1354 ngày 28/06/2023**:
#   - Giao cho Bộ môn Toán Kinh tế, Khoa Toán chủ trì
#   - Từ khóa 66: môn học trở thành **môn bắt buộc toàn trường**, giảng dạy năm thứ 2
#   - Môn học thay thế chuẩn đầu ra Tin học
#   - Điều kiện tiên quyết: “Toán cho các nhà kinh tế” (tương đương Giải tích 1 giản lược)
# **Mục tiêu tổng thể**:
#   - Trang bị tư duy Khoa học dữ liệu và Trí tuệ nhân tạo cho sinh viên
#
# ## Từ phía Trường Công nghệ
#
# - **Tháng 10/2024**: Đưa môn học “KHDL” vào kế hoạch & ngân sách – *Không được duyệt*
#
# - **Tháng 04/2024: Họp Hội đồng chuyên môn**:
#   - Thành lập nhóm chuyên môn xây dựng môn học
#   - Ý tưởng ban đầu: không code, tập trung vào **kiến thức chung + trực quan hóa (POWER BI)**
#   - Khó khăn:
#     - Thiếu giáo trình phù hợp
#     - Thiếu giảng viên có chuyên môn
#
# - **Từ 01/06/2025**:
#
#   - TS. Phạm Xuân Lâm đề xuất sử dụng **Smartdoc**
#     - Hỗ trợ sinh viên không biết lập trình
#     - Triển khai rộng dễ dàng
#     - Hỗ trợ Python, phổ biến, có nhiều tài nguyên từ các trường uy tín
#
# - Thống nhất: giảng dạy bằng ngôn ngữ **Python**
#
# ## Tiến độ phát triển nội dung môn học
#
# - **15/07/2025**: Hoàn thành giáo trình sơ bộ “Khoa học dữ liệu trong Kinh tế và Kinh doanh (Python)”
# - **22/07/2025**: Thống nhất đề cương môn học
# - **24/07/2025**: Họp triển khai môn học toàn trường
# - **30/07/2025**: Thống nhất nội dung (buổi 1)
#
# ## Danh sách các môn học/khóa học tham khảo
#
# | Tên trường / Doanh nghiệp                     | Tên môn học                                    | Ngôn ngữ sử dụng   | Ghi chú                                                                 |
# |----------------------------------------------|------------------------------------------------|--------------------|-------------------------------------------------------------------------|
# | Đại học Bách Khoa Hà Nội                     | Giới thiệu Khoa học dữ liệu (IT3080)          | Python             | Môn nền tảng cho sinh viên CNTT, Toán tin, tự động hóa...              |
# | ĐHQG TP.HCM – ĐH KHTN                         | Nhập môn Khoa học Dữ liệu                      | Python             | Học phần cơ sở ngành, có phiên bản đào tạo trực tuyến                  |
# | Đại học Kinh tế Đà Nẵng                       | Nhập môn Khoa học Dữ liệu ứng dụng             | Python hoặc R         | Gắn với ứng dụng trong kinh doanh, giảng dạy cho khối Kinh tế         |
# | Harvard University                            | Introduction to Data Science              | R                  | Khóa học edX, giảng viên Rafael Irizarry, học miễn phí dạng audit     |
# | MIT                                           | Introduction to Computational Thinking and Data Science        | Python             | Course 6.0002, dạy tư duy tính toán và khoa học dữ liệu cơ bản         |
# | UC Berkeley                                   | Foundations of Data Science (Data 8)           | Python             | Dạy quy mô lớn (>10.000 SV), tài nguyên mở tại [data8.org](https://data8.org) |
# | IBM (Coursera)                                | IBM Data Science Professional Certificate      | Python / SQL       | Chuỗi 10 khóa học, hướng dẫn phân tích dữ liệu, ML, trực quan hóa     |
# | Google (Coursera)                             | Google Advanced Data Analytics Certificate     | Python / SQL       | Hướng tới phân tích chuyên sâu, ML cơ bản, không yêu cầu nền tảng     |
#
#
# ## Mục tiêu môn học
#
# 1. Hiểu nguyên lý của Khoa học dữ liệu
# 2. Hiểu được vai trò và quy trình khoa học dữ liệu trong thực tiễn.
# 3. Hình thành tư duy đặt câu hỏi, suy luận và ra quyết định dựa trên dữ liệu.
# 4. Áp dụng quy trình KHDL cho các vấn đề đơn giản trong kinh tế & kinh doanh
#
# ## Thông tin môn học
#
# **Tên**: Khoa học dữ liệu cơ bản trong Kinh tế và Kinh doanh
# **Mã môn**: `FDA.6.1.2.68.V`
#
# **Đơn vị phụ trách chuyên môn**: Khoa Khoa học Dữ liệu & Trí tuệ Nhân tạo
#   - Chịu trách nhiệm nội dung
#   - Quản lý hành chính, phân công giảng viên
#
# **Đề cương chi tiết**: [tại đây](https://courses.neu.edu.vn/syllabus/K66/vi/FDA61201V)
#
# **Giáo trình & Tài liệu**: 100% online
#   - Giáo trình: [https://nct-neu.github.io/Sach_Khoa_hoc_du_lieu_python](https://nct-neu.github.io/Sach_Khoa_hoc_du_lieu_python)
#   - Mã nguồn, tài liệu, dữ liệu sử dụng cho môn học: [https://github.com/NCT-NEU/Sach_Khoa_hoc_du_lieu_python](https://github.com/NCT-NEU/Sach_Khoa_hoc_du_lieu_python)
#
# **Ngôn ngữ lập trình**: Python
#
# **Soạn bài giảng**: sử dụng Python + Smartdoc (phát triển bởi Khoa CNTT)
#   - Hỗ trợ sinh viên không biết lập trình
#   - Triển khai rộng dễ dàng
#   - Hỗ trợ Python, phổ biến, có nhiều tài nguyên từ các trường uy tín
#   - [Bài giảng 1: Giới thiệu về Khoa học dữ liệu](https://fit.neu.edu.vn/doc/huynqtkt@neu.edu.vn/B%C3%A0i%20gi%E1%BA%A3ng%20-%20Gi%E1%BB%9Bi%20thi%E1%BB%87u%20v%E1%BB%81%20Khoa%20h%E1%BB%8Dc%20d%E1%BB%AF%20li%E1%BB%87u.ipynb?display=slide#18)
#
# ## Kế hoạch giảng dạy kỳ 04/08
#
# **Hình thức**: Lecture + Tutorial
#
# **Giảng viên**:
#   - Tất cả các khoa có thể đăng ký tham gia
#   - Phải qua đánh giá của nhóm chuyên môn
#
# **Số lượng giảng viên**:
#   - **Lecturers (9)**:
#     - Khoa KHDL: 5
#     - Khoa CNTT: 2
#     - Khoa HTTTQL: 1
#     - Khoa Toán KT: 1
#   - **Tutors (17)**:
#     - Khoa KHDL: 5
#     - Khoa CNTT: 6
#     - Khoa HTTTQL: 2
#     - Khoa Toán KT: 2
#     - Khoa KHCS: 2
#
# **Số lớp đăng ký kỳ 04/08**:
#   - 10 lớp chính quy
#   - 13 lớp chương trình CLC
#
# ## Kế hoạch phát triển môn học
#
# 1. Phát triển các phiên bản khác: Tiếng Anh, Đào tạo từ xa...
# 2. Đưa bài giảng & nội dung lên nền tảng online 100%
# 3. Định hướng môn học trở thành **chứng chỉ**
# 4. Thay thế **chuẩn đầu ra Tin học**
#
# ## Tập huấn cho giảng viên
#
# - Phân phối slides và bài giảng cho các khoa phù hợp
# - Giảng viên **core** đảm nhiệm từ kỳ 04/08
# - Các giảng viên mới: tham dự lớp họ + học online trên coursera (IBM Data Science Certificate)
#
# ## Kiến nghị với Đại học
#
# 1. Công nhận giáo trình online 100%
# 2. Cấp ngân sách phát triển môn học
# 3. Cơ chế khuyến khích nhóm giảng viên core
# 4. Đầu tư **cơ sở hạ tầng (server, mạng)** phục vụ dạy học diện rộng

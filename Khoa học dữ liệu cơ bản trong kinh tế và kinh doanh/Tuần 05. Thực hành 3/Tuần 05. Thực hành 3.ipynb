# %% [markdown]
# # Yêu cầu thực hành

# %% [markdown]
# *Làm việc với Pandas theo các yêu cầu sau:
# Bài tập 1: Đọc dữ liệu từ file Pandas và cho biết số lượng bản ghi, số lượng column có trong file đồng thời hiện lên 5 bản ghi đầu tiên của file
# Đoạn code tương ứng
# Bài tập 2: Sử dụng pandas để hiện thị thống kê cơ bản về trường dữ liệu có trong file
# (sử dụng describe), sử dụng histogram
# Bài tập 3: Thao tác với các cột dữ liệu
# Tạo ra 1 cột mới bằng cách ghép dữ liệu từ 2 cột
# Bài tập 4: Lọc dữ liệu
# Lọc dữ liệu với điều kiện giá trị 1 cột lớn hơn bao nhiêu điểm
# Bài tập 5: Sắp xếp dữ liệu
# Sắp xếp dữ liệu theo cột điểm và giảm dần
# Sắp xếp dữ liệu cột điểm giảm dần, nếu bằng điểm, tiếp tục giảm dần theo môn Toán
# Bài tập 6: Sử dụng hàm kết hợp với pandas sinh ra dữ liệu cột
# Hãy tạo ra cột mới tên là Xếp loại cho phép kiểm tra dữ liệu từ cột điểm với điều kiện nếu Tổng điểm > 27 được xếp loại "Xuất sắc", trái lại để trống.
# Bài tập 7: Ghép dữ liệu từ 2 data frame
# Bài tập 8: Lưu dữ liệu vào 2 mới

# %% [markdown]
# # Bài tập 1: Thực hành

# %%
# import thu vien va tao ra mot data frame
import pandas as pd
df1 = pd.DataFrame (

{
  'Name':['Simon', 'Kate', 'Francis', 'Laura', 'Marry', 'Julian', 'Rosie'],
    'Height':[180,165,170,164,163,175,166],
    'Weight': [85,65,68,45,43,72,46],
    'Pref_food': ['steak', 'pizza', 'pasta', 'pizza', 'vegetables','steak','seafood'],
    'Sex':['m', 'f','m','f', 'f','m','f']
}
)
df1
# Out:
#       Name  Height  Weight   Pref_food Sex
# 0    Simon     180      85       steak   m
# 1     Kate     165      65       pizza   f
# 2  Francis     170      68       pasta   m
# 3    Laura     164      45       pizza   f
# 4    Marry     163      43  vegetables   f
# 5   Julian     175      72       steak   m
# 6    Rosie     166      46     seafood   f

# %%
#Describe dataframe
df1.describe()
# Out:
#            Height     Weight
# count    7.000000   7.000000
# mean   169.000000  60.571429
# std      6.377042  16.154021
# min    163.000000  43.000000
# 25%    164.500000  45.500000
# 50%    166.000000  65.000000
# 75%    172.500000  70.000000
# max    180.000000  85.000000

# %%
# Lay ten cac cot
df1.columns
# Out:
# Index(['Name', 'Height', 'Weight', 'Pref_food', 'Sex'], dtype='object')

# %%
# set index for data frame
df1.set_index('Name')
# Out:
#          Height  Weight   Pref_food Sex
# Name
# Simon       180      85       steak   m
# Kate        165      65       pizza   f
# Francis     170      68       pasta   m
# Laura       164      45       pizza   f
# Marry       163      43  vegetables   f
# Julian      175      72       steak   m
# Rosie       166      46     seafood   f

# %%
#Lay ra top dau va phan cuoi cua ban ghi trong df
df1.head()
df1.tail(3)
# Out:
#      Name  Height  Weight   Pref_food Sex
# 4   Marry     163      43  vegetables   f
# 5  Julian     175      72       steak   m
# 6   Rosie     166      46     seafood   f

# %%
# Lay top 3 phan tu dau tien
df1[:3]
# Lay phan tu thu 4 trro di
df1[:4]
#df1[]
# Out:
#       Name  Height  Weight Pref_food Sex
# 0    Simon     180      85     steak   m
# 1     Kate     165      65     pizza   f
# 2  Francis     170      68     pasta   m
# 3    Laura     164      45     pizza   f

# %%
# Review ve cau truc va dac diem du lieu cua df1
df1.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 7 entries, 0 to 6
# Data columns (total 5 columns):
#  #   Column     Non-Null Count  Dtype
# ---  ------     --------------  -----
#  0   Name       7 non-null      object
#  1   Height     7 non-null      int64
#  2   Weight     7 non-null      int64
#  3   Pref_food  7 non-null      object
#  4   Sex        7 non-null      object
# dtypes: int64(2), object(3)
# memory usage: 412.0+ bytes

# %% [markdown]
# # Bài tập 2: Sắp xếp danh sách

# %%
#Sap xep theo tieu chi la 1 cot
df1.sort_values(by = 'Sex')
# Out:
#       Name  Height  Weight   Pref_food Sex
# 1     Kate     165      65       pizza   f
# 3    Laura     164      45       pizza   f
# 4    Marry     163      43  vegetables   f
# 6    Rosie     166      46     seafood   f
# 0    Simon     180      85       steak   m
# 2  Francis     170      68       pasta   m
# 5   Julian     175      72       steak   m

# %%
#Sap xep theo tieu chi 1 cot weight, giam dan
df1.sort_values(by = 'Weight', ascending = True)
# Out:
#       Name  Height  Weight   Pref_food Sex
# 4    Marry     163      43  vegetables   f
# 3    Laura     164      45       pizza   f
# 6    Rosie     166      46     seafood   f
# 1     Kate     165      65       pizza   f
# 2  Francis     170      68       pasta   m
# 5   Julian     175      72       steak   m
# 0    Simon     180      85       steak   m

# %%
#Sap xep theo tieu chi 1 cot weight, giam dan
df1.sort_values(by = 'Weight', ascending = False)
# Out:
#       Name  Height  Weight   Pref_food Sex
# 0    Simon     180      85       steak   m
# 5   Julian     175      72       steak   m
# 2  Francis     170      68       pasta   m
# 1     Kate     165      65       pizza   f
# 6    Rosie     166      46     seafood   f
# 3    Laura     164      45       pizza   f
# 4    Marry     163      43  vegetables   f

# %%
#Sap xep theo tieu chi la nhieu cot
# Sap xep theo gioi tinh
# Neu trong cung gioi tinh --> Sap xep theo Weight (tang dan)
df1.sort_values(by = ['Sex', 'Weight'])
# Out:
#       Name  Height  Weight   Pref_food Sex
# 4    Marry     163      43  vegetables   f
# 3    Laura     164      45       pizza   f
# 6    Rosie     166      46     seafood   f
# 1     Kate     165      65       pizza   f
# 2  Francis     170      68       pasta   m
# 5   Julian     175      72       steak   m
# 0    Simon     180      85       steak   m

# %%
# Sap xep theo tieu chi la nhieu cot
# Sap xep theo gioi tinh
# Neu trong cung gioi tinh --> Sap xep theo Weight (giam dan)
df1.sort_values(by =['Sex', 'Weight'], ascending=[True, False])
# Out:
#       Name  Height  Weight   Pref_food Sex
# 1     Kate     165      65       pizza   f
# 6    Rosie     166      46     seafood   f
# 3    Laura     164      45       pizza   f
# 4    Marry     163      43  vegetables   f
# 0    Simon     180      85       steak   m
# 5   Julian     175      72       steak   m
# 2  Francis     170      68       pasta   m

# %%
# Truong hop sap xep theo mot cot (truong du lieu),
# neu cot do co gia tri null thi se dat len dong dau tien hay dong cuoi cung
df1.sort_values(by = 'Weight', na_position = 'last')
# Out:
#       Name  Height  Weight   Pref_food Sex
# 4    Marry     163      43  vegetables   f
# 3    Laura     164      45       pizza   f
# 6    Rosie     166      46     seafood   f
# 1     Kate     165      65       pizza   f
# 2  Francis     170      68       pasta   m
# 5   Julian     175      72       steak   m
# 0    Simon     180      85       steak   m

# %% [markdown]
# # Bài tập 3: Làm việc với Index

# %% [markdown]
# Lam viec voi index:
# 1. KHi chua co index --> mac dinh la 0,1,2,3
# 2. Tao index cho dataframe tren mot cot --> giup co kha nang sau nay truy xuat cac phan tu thong qua cot index do
# 3. Check index hien thoi cua mot data frame bao gom nhung phan tu nao va dang nam tren cot nao
# 4. Reset index
# 5. Tao lai index

# %%
# set index cho data frame
df1.set_index('Name', inplace = True)

# %%
# Lay ra tap index cua dataframe
df1.index
# Out:
# Index(['Simon', 'Kate', 'Francis', 'Laura', 'Marry', 'Julian', 'Rosie'], dtype='object', name='Name')

# %%
# reset index
df1.reset_index()
#cot name tro lai cot binh thuong
# Out:
#       Name  Height  Weight   Pref_food Sex
# 0    Simon     180      85       steak   m
# 1     Kate     165      65       pizza   f
# 2  Francis     170      68       pasta   m
# 3    Laura     164      45       pizza   f
# 4    Marry     163      43  vegetables   f
# 5   Julian     175      72       steak   m
# 6    Rosie     166      46     seafood   f

# %%
#recheck lai index
df1 = df1.reset_index() # cot name tro lai thanh cot bt
df1
# Out:
#       Name  Height  Weight   Pref_food Sex
# 0    Simon     180      85       steak   m
# 1     Kate     165      65       pizza   f
# 2  Francis     170      68       pasta   m
# 3    Laura     164      45       pizza   f
# 4    Marry     163      43  vegetables   f
# 5   Julian     175      72       steak   m
# 6    Rosie     166      46     seafood   f

# %%
df1.index
# Out:
# RangeIndex(start=0, stop=7, step=1)

# %%
# TRUY CAP THONG QUA INDEX
df1 = df1.reset_index()

# %%
df1.set_index('Pref_food', inplace = True)
df1.head()
# Out:
#             index     Name  Height  Weight Sex
# Pref_food
# steak           0    Simon     180      85   m
# pizza           1     Kate     165      65   f
# pasta           2  Francis     170      68   m
# pizza           3    Laura     164      45   f
# vegetables      4    Marry     163      43   f

# %%
# Truy cap thong tin index (loc)
df1.loc['pizza']
# Out:
#            index   Name  Height  Weight Sex
# Pref_food
# pizza          1   Kate     165      65   f
# pizza          3  Laura     164      45   f

# %%
df1.loc['steak']
# Out:
#            index    Name  Height  Weight Sex
# Pref_food
# steak          0   Simon     180      85   m
# steak          5  Julian     175      72   m

# %%
# Truy cap vao 1 phan tu trong bang thong tin illoc
df1
# Out:
#             index     Name  Height  Weight Sex
# Pref_food
# steak           0    Simon     180      85   m
# pizza           1     Kate     165      65   f
# pasta           2  Francis     170      68   m
# pizza           3    Laura     164      45   f
# vegetables      4    Marry     163      43   f
# steak           5   Julian     175      72   m
# seafood         6    Rosie     166      46   f

# %%
# Lay thong qua vi tri
# Lay ra dong dau tien
df1.iloc[0]
# Out:
# index         0
# Name      Simon
# Height      180
# Weight       85
# Sex           m
# Name: steak, dtype: object

# %% [markdown]
# #Bài tập 3B. Lọc dữ liệu thông qua index

# %%
df1.iloc[2:4]
# Out:
#            index     Name  Height  Weight Sex
# Pref_food
# pasta          2  Francis     170      68   m
# pizza          3    Laura     164      45   f

# %%
# Lay ra mot cot 0(nghia la lay ra toan bo cac hang cua chi cot 0)
df1.iloc[:,0]# Cau truc cua iloc[:,:]
# Out:
# Pref_food
# steak         0
# pizza         1
# pasta         2
# pizza         3
# vegetables    4
# steak         5
# seafood       6
# Name: index, dtype: int64

# %%
# Lay 1 tap con (truong hop nay la toan bo bang)
df1.iloc[:,:]
# Out:
#             index     Name  Height  Weight Sex
# Pref_food
# steak           0    Simon     180      85   m
# pizza           1     Kate     165      65   f
# pasta           2  Francis     170      68   m
# pizza           3    Laura     164      45   f
# vegetables      4    Marry     163      43   f
# steak           5   Julian     175      72   m
# seafood         6    Rosie     166      46   f

# %%
# # Lay 1 tap con (truong hop nay la phan den phan tu so 3 cua hang & so 3 cua cot)
df1.iloc[1:4,1:4]
# Out:
#               Name  Height  Weight
# Pref_food
# pizza         Kate     165      65
# pasta      Francis     170      68
# pizza        Laura     164      45

# %% [markdown]
# # Bài tập 4: Lọc dữ liệu

# %%
# Loc du lieu voi dieu kien la mot mien gia tri
df1[df1.Height>170]
# Out:
#            index    Name  Height  Weight Sex
# Pref_food
# steak          0   Simon     180      85   m
# steak          5  Julian     175      72   m

# %%
#Loc voi bieu thuc dieu kien
# Gioi tinh la f
# Chieu cao lon hon 163
df1[(df1.Height>163)& (df1.Sex=='f')]
# Out:
#            index   Name  Height  Weight Sex
# Pref_food
# pizza          1   Kate     165      65   f
# pizza          3  Laura     164      45   f
# seafood        6  Rosie     166      46   f

# %% [markdown]
# # Bài tập 5: Làm việc tạo cột dữ liệu mới

# %%
# Chen mot cot moi vao data frame
# Truong hop nay tao ra cot moi banag cach lay cot chieu cao chia cho 100
# Cot moi them se nam pw vi tri cot cuoi bang
df2 = df1.copy()
df2['new_col'] = df2.Height/100
df2
# Out:
#             index     Name  Height  Weight Sex  new_col
# Pref_food
# steak           0    Simon     180      85   m     1.80
# pizza           1     Kate     165      65   f     1.65
# pasta           2  Francis     170      68   m     1.70
# pizza           3    Laura     164      45   f     1.64
# vegetables      4    Marry     163      43   f     1.63
# steak           5   Julian     175      72   m     1.75
# seafood         6    Rosie     166      46   f     1.66

# %%
# Co the chen mot cot moi vao vi tri nao do
# Truong hop bay se chen mot cot moi vao vi tri so 5
df2.insert(3,column = 'new_col4', value = df2.Height/100)
print(df2.head(2))
# Out:
#            index   Name  Height  new_col4  Weight Sex  new_col
# Pref_food
# steak          0  Simon     180      1.80      85   m     1.80
# pizza          1   Kate     165      1.65      65   f     1.65

# %%
#Group by du lieu
df1
# Out:
#             index     Name  Height  Weight Sex
# Pref_food
# steak           0    Simon     180      85   m
# pizza           1     Kate     165      65   f
# pasta           2  Francis     170      68   m
# pizza           3    Laura     164      45   f
# vegetables      4    Marry     163      43   f
# steak           5   Julian     175      72   m
# seafood         6    Rosie     166      46   f

# %%
#Gia su se gom nhung ban ghi co gioi tinh giong nhau vao cung mot nhom
# Thi se lam dc gi
df1.sort_values(by = 'Sex')
#Khi do se khong con tung ban ghi chi tiet nhu hien tai
groupSex = df1.groupby('Sex')

# %% [markdown]
# #Bài tập 6: Nhóm dữ liệu

# %%
#Gia su se gom nhung ban ghi co gioi tinh giong nhau vao cung mot nhom
# Thi se lam dc gi
df1.sort_values(by = 'Sex')
#Khi do se khong con tung ban ghi chi tiet nhu hien tai
groupSex = df1.groupby('Sex')

# %%
# Sau khi group xong -->xem cac group
groupSex.groups
# Out:
# {'f': ['pizza', 'pizza', 'vegetables', 'seafood'], 'm': ['steak', 'pasta', 'steak']}

# %%
#Xem thong tin chi tiet cua tung group
for names, groups in groupSex:
    print(names)
    print(groups)
# Out:
# f
#             index   Name  Height  Weight Sex
# Pref_food
# pizza           1   Kate     165      65   f
# pizza           3  Laura     164      45   f
# vegetables      4  Marry     163      43   f
# seafood         6  Rosie     166      46   f
# m
#            index     Name  Height  Weight Sex
# Pref_food
# steak          0    Simon     180      85   m
# pasta          2  Francis     170      68   m
# steak          5   Julian     175      72   m

# %%
#tu day co the lay ra tung group
m_groupSex = groupSex.get_group('m')
m_groupSex
# Out:
#            index     Name  Height  Weight Sex
# Pref_food
# steak          0    Simon     180      85   m
# pasta          2  Francis     170      68   m
# steak          5   Julian     175      72   m

# %%
#Co the lay ra mot group roi thong ke no
m_groupSex.describe()
# Out:
#           index  Height     Weight
# count  3.000000     3.0   3.000000
# mean   2.333333   175.0  75.000000
# std    2.516611     5.0   8.888194
# min    0.000000   170.0  68.000000
# 25%    1.000000   172.5  70.000000
# 50%    2.000000   175.0  72.000000
# 75%    3.500000   177.5  78.500000
# max    5.000000   180.0  85.000000

# %%
#Co the group by theo nhieu cot
#Tao ra mot phan cap ve du lieu
grouped2 = df1.groupby(['Sex', 'Pref_food'])
#Lay ra thong ke ve co cua tung nhom
grouped2.size()
# Out:
# Sex  Pref_food
# f    pizza         2
#      seafood       1
#      vegetables    1
# m    pasta         1
#      steak         2
# dtype: int64

# %%
grouped2.describe()
# Out:
#                index                                           Height         \
#                count mean       std  min   25%  50%   75%  max  count   mean
# Sex Pref_food
# f   pizza        2.0  2.0  1.414214  1.0  1.50  2.0  2.50  3.0    2.0  164.5
#     seafood      1.0  6.0       NaN  6.0  6.00  6.0  6.00  6.0    1.0  166.0
#     vegetables   1.0  4.0       NaN  4.0  4.00  4.0  4.00  4.0    1.0  163.0
# m   pasta        1.0  2.0       NaN  2.0  2.00  2.0  2.00  2.0    1.0  170.0
#     steak        2.0  2.5  3.535534  0.0  1.25  2.5  3.75  5.0    2.0  177.5
#
#                 ...                Weight                                      \
#                 ...     75%    max  count  mean        std   min    25%   50%
# Sex Pref_food   ...
# f   pizza       ...  164.75  165.0    2.0  55.0  14.142136  45.0  50.00  55.0
#     seafood     ...  166.00  166.0    1.0  46.0        NaN  46.0  46.00  46.0
#     vegetables  ...  163.00  163.0    1.0  43.0        NaN  43.0  43.00  43.0
# ...

# %%
#Xem thong ke chi tiet cua tung group
for names, groups in grouped2:
    print(names)
    print(groups)
# Out:
# ('f', 'pizza')
#            index   Name  Height  Weight Sex
# Pref_food
# pizza          1   Kate     165      65   f
# pizza          3  Laura     164      45   f
# ('f', 'seafood')
#            index   Name  Height  Weight Sex
# Pref_food
# seafood        6  Rosie     166      46   f
# ('f', 'vegetables')
#             index   Name  Height  Weight Sex
# Pref_food
# vegetables      4  Marry     163      43   f
# ('m', 'pasta')
#            index     Name  Height  Weight Sex
# Pref_food
# pasta          2  Francis     170      68   m
# ('m', 'steak')
#            index    Name  Height  Weight Sex
# Pref_food
# steak          0   Simon     180      85   m
# steak          5  Julian     175      72   m

# %%
#Tinh so luong cua tung nhom
df1.groupby(['Sex', 'Pref_food']).agg({'Name':'count'})
# Out:
#                 Name
# Sex Pref_food
# f   pizza          2
#     seafood        1
#     vegetables     1
# m   pasta          1
#     steak          2

# %%
# Tinh % cua tung nhom
(df1.groupby(['Sex', 'Pref_food']).agg({'Name':'count'})
.groupby (level = 0)
.apply(lambda x: 100*x/float(x.sum()))
 )
# Out:
# /tmp/ipython-input-45-1146189850.py:4: FutureWarning: Calling float on a single element Series is deprecated and will raise a TypeError in the future. Use float(ser.iloc[0]) instead
#   .apply(lambda x: 100*x/float(x.sum()))
#                          Name
# Sex Sex Pref_food
# f   f   pizza       50.000000
#         seafood     25.000000
#         vegetables  25.000000
# m   m   pasta       33.333333
#         steak       66.666667

# %% [markdown]
# # **Câu hỏi ôn tập về Numpy**

# %%
import numpy as np

# %% [markdown]
# ## **Bài thực hành 1**

# %% [markdown]
# ### **Đề bài**
#
# Cho trước ma trận `A` như dưới đây:
# 1. Tạo một ma trận `B` bằng cách ép kiểu `A` sang kiểu số nguyên (int). In cả hai ma trận và kiểu dữ liệu tương ứng
# 2. Tạo một vector 1D ``u`` có kiểu float64 chứa 3 phần tử: ``[0.5, 1.5, 2.5]``. Thực hiện phép cộng giữa ma trận số nguyên ``B`` và vector `u` để tạo ra ma trận `C`.In ra ma trận D và kiểu dữ liệu của nó.
# 3. Tạo một vector 1D `v` kiểu int32 chứa 3 phần tử: `[10, 20, 30]`. Thực hiện phép cộng giữa ma trận số nguyên `B` và vector `v` để tạo ra ma trận `D`. In ra ma trận D và kiểu dữ liệu của nó.
#
# (So sánh và giải thích kiểu dữ liệu của C và D)

# %%
import numpy as np
A = np.array([
    [5.1, 8.7, 3.3],
    [4.4, 0.9, 9.5],
    [6.2, 7.5, 1.8]
])

# %% [markdown]
# ### **Đáp án**

# %%
import numpy as np
# 1. Ma trận B
# Ma trận A
print(f"Ma trận A: \n {A}")
print(f"Kiểu dữ liệu của ma trận A: {A.dtype}\n")

# Ma trận B
B = A.astype(int)
print(f"Ma trận B: \n {B}")
print(f"Kiểu dữ liệu của ma trận B: {B.dtype}\n")

# 2. Ma trận C
u = np.array([0.5, 1.5, 2.5], dtype=np.float64)
print(f"Vector u: {u}")
print(f"Kiểu dữ liệu của vector u: {u.dtype}")
C = B + u
print(f"Ma trận C: \n {C}")
print(f"Kiểu dữ liệu của ma trận C: {C.dtype}\n")

# 3. Ma trận D
v = np.array([10, 20, 30], dtype=np.int32)
print(f"Vector u: {v}")
print(f"Kiểu dữ liệu của vector u: {v.dtype}")
D = B + v
print(f"Ma trận D: \n {D}")
print(f"Kiểu dữ liệu của ma trận D: {D.dtype}")

# %% [markdown]
# ## **Bài thực hành 2**

# %% [markdown]
# ### **Đề bài**
#
# 1. Tạo ma trận M kích thước 6x6 chứa các số từ 0 đến 35
# 2. Sử dụng slicing, trích xuất một ma trận con P là vùng trung tâm 4x4 của M
# 3. Sử dụng fancy indexing, chọn các hàng 0 và 3 của P
# 4. Gán tất cả các giá trị trong các cột 1 và 2 của ma trận M gốc thành -99. In lại ma trận M
# 5. Từ ma trận M đã được cập nhật ở bước 2, hãy sử dụng kết hợp các kỹ thuật indexing để trích xuất và in ra tất cả các giá trị lớn hơn 20 nhưng chỉ nằm trong các cột có chỉ số lẻ (1, 3, 5)

# %% [markdown]
# ### **Đáp án**

# %%
import numpy as np
# 1. Tạo ma trận M
M = np.arange(36).reshape(6, 6)
print("Ma trận M 6x6")
print(M)

# 2. Trích xuất vùng trung tâm 4x4
# Hàng từ 1 đến 4, cột từ 1 đến 4
P = M[1:5, 1:5]
print("\n Ma trận con P (vùng trung tâm 4x4)")
print(P)

# 3. Chọn các hàng 0 và 3 của P
selected_rows_from_P = P[[0, 3], :]
print("\n Hàng 0 và 3 của P")
print(selected_rows_from_P)

# 4. Gán giá trị cho các cột 1 và 2 của M
M[:, [1, 2]] =  -99
print("\n Ma trận M sau khi gán giá trị cho cột 1 và 2")
print(M)

# 5. Trích xuất giá trị theo điều kiện kết hợp
# Lấy ra các cột lẻ từ ma trận đã bị thay đổi
odd_columns = M[:, [1, 3, 5]]

# Tạo một mask boolean cho các giá trị > 20 chỉ trên các cột này
mask = odd_columns > 20

# Sử dụng mask để lấy ra các giá trị thỏa mãn
result = odd_columns[mask]

print("\n Các giá trị > 20 chỉ nằm trong các cột lẻ (1, 3, 5)")
print(result)

# %% [markdown]
# ## **Bài thực hành 3**

# %% [markdown]
# ### **Đề bài**
#
# 1. Tạo ma trận `data` kích thước 4x5 với các số nguyên ngẫu nhiên từ 10 đến 99
# 2. Tính và in ra ma trận chuyển vị `data_T`
# 3. Tính giá trị lớn nhất (max) và nhỏ nhất (min) cho từng hàng của ma trận `data`
# 4. Sử dụng `argmax`, tìm chỉ số của cột chứa giá trị lớn nhất cho mỗi hàng

# %% [markdown]
# ### **Đáp án**

# %%
import numpy as np
# 1. Tạo ma trận data
data = np.random.randint(10, 100, size=(4, 5))
print("Ma trận data 4x5")
print(data)

# 2. Chuyển vị
data_T = data.T
print("\n Ma trận chuyển vị data_T 5x4")
print(data_T)

# 3. Tính max và min cho từng hàng
max_in_rows = data.max(axis=1)
min_in_rows = data.min(axis=1)
print("\n Giá trị lớn nhất trong mỗi hàng")
print(max_in_rows)
print("\n Giá trị nhỏ nhất trong mỗi hàng")
print(min_in_rows)

# 4. Tìm chỉ số của giá trị lớn nhất trong mỗi hàng
col_indices_of_max = data.argmax(axis=1)
print("\n Chỉ số cột chứa giá trị max cho mỗi hàng")
print(col_indices_of_max)

# %% [markdown]
# ## **Bài thực hành 4**

# %% [markdown]
# ### **Đề bài**
#
# Một công ty sản xuất 3 loại sản phẩm. Chi phí cho mỗi sản phẩm gồm: chi phí nguyên vật liệu, chi phí nhân công, và chi phí vận hành.
#
# 1. Tạo ma trận chi phí costs kích thước 3x3, trong đó hàng đại diện cho sản phẩm, cột đại diện cho loại chi phí.
#
#     Sản phẩm A: `[10, 5, 2]`
#
#     Sản phẩm B: `[12, 7, 3]`
#
#     Sản phẩm C: `[9, 4, 2.5]`
#
# 2. Giả sử số lượng sản xuất trong tháng là production_volume = `[1000, 500, 1500]` cho 3 sản phẩm A, B, C.
#
# 3. Tính tổng chi phí cho từng loại (nguyên vật liệu, nhân công, vận hành) trên toàn bộ sản lượng.
#
# 4. Tính tổng chi phí sản xuất cho từng sản phẩm (không tính theo số lượng, chỉ tính trên đơn vị).

# %% [markdown]
# ### **Đáp án**

# %%
import numpy as np
# 1. Tạo ma trận chi phí
costs = np.array([
    [10, 5, 2],    # Sản phẩm A
    [12, 7, 3],    # Sản phẩm B
    [9, 4, 2.5]    # Sản phẩm C
])
print("Ma trận chi phí (Sản phẩm x Loại chi phí)")
print(costs)

# 2. Tạo vector số lượng
production_volume = np.array([1000, 500, 1500])

# 3. Tính tổng chi phí cho từng loại
# Reshape production_volume thành (3, 1) để broadcast qua các cột của costs
# Phép nhân (3, 3) với (3, 1) sẽ tạo ra ma trận chi phí tổng cho mỗi sản phẩm
total_costs_per_product_type = costs * production_volume.reshape(3, 1)
# Tính tổng theo từng cột (axis=0) để ra chi phí cho mỗi loại
total_cost_by_type = total_costs_per_product_type.sum(axis=0)

print("\nTổng chi phí cho từng loại (NVL, Nhân công, Vận hành)")
print(total_cost_by_type)

# 4. Tính tổng chi phí cho từng sản phẩm (trên 1 đơn vị)
# Tính tổng theo từng hàng (axis=1)
total_cost_per_unit = costs.sum(axis=1)
print("\n Tổng chi phí trên một đơn vị cho từng sản phẩm")
print(total_cost_per_unit)

# %% [markdown]
# ## **Bài thực hành 5**

# %% [markdown]
# ### **Đề bài**
# Hàm Sigmoid là một hàm kích hoạt phổ biến trong học máy, được định nghĩa bởi công thức:
# $$ \sigma(x) = \frac{1}{1 + e^{-x}}
#  $$
#
# 1. Sử dụng np.arange, tạo một mảng `x` chứa các giá trị từ -3 đến 3, với bước nhảy là 0.5.
#
# 2. Viết code NumPy để tính giá trị của hàm Sigmoid cho tất cả các phần tử trong `x`. In kết quả ra màn hình.

# %% [markdown]
# ### **Đáp án**

# %%
import numpy as np
# 1. Tạo mảng x
x = np.arange(-3, 3.5, 0.5)
print("Mảng x đầu vào:")
print(np.round(x, 2))

# 2. Tính hàm Sigmoid
# Phép toán được thực hiện trên từng phần tử của mảng một cách tự động (vector hóa)
sigmoid_x = 1 / (1 + np.exp(-x))

print("\n Kết quả của hàm Sigmoid")
print(np.round(sigmoid_x, 4))

# %% [markdown]
# ## **Bài thực hành 6**

# %% [markdown]
# ### **Đề bài**
# Một cách khác để giải hệ phương trình tuyến tính `Ax=b` (khi ma trận `A` khả nghịch) là sử dụng ma trận nghịch đảo, dựa trên công thức: $x=A^{-1}b$
#
# Cho hệ phương trình sau:
# $$ \begin{aligned}
# 2x+3y+z &= 9 \\
# x+2y+3z &= 6 \\
# 3x+y+2z &= 8 \\
# \end{aligned}
# $$
#
# 1. Biểu diễn hệ phương trình dưới dạng ma trận `A` và vector `b`.
#
# 2. Một ma trận chỉ có ma trận nghịch đảo khi định thức (determinant) của nó khác 0. Hãy tính định thức của A bằng np.linalg.det để kiểm tra xem A có khả nghịch hay không.
#
# 3. Tính ma trận nghịch đảo $A^{-1}$ của A.
# 4. Sử dụng ma trận nghịch đảo vừa tìm được để tìm nghiệm `x` của hệ phương trình theo công thức $x=A^{-1}b$
#
# 5. Kiểm tra lại kết quả bằng cách nhân A với nghiệm x vừa tìm được.

# %% [markdown]
# ### **Đáp án**

# %%
import numpy as np
# 1. Tạo ma trận A và vector b
A = np.array([
    [2, 3, 1],
    [1, 2, 3],
    [3, 1, 2]
])
b = np.array([9, 6, 8])
print("Ma trận A")
print(A)
print("Vector b")
print(b)

# 2. Tính định thức của A
determinant = np.linalg.det(A)
print(f"\nĐịnh thức của A là: {np.round(determinant, 2)}")

if determinant == 0:
    print("Định thức bằng 0, ma trận không khả nghịch.")
else:
    print("Định thức khác 0, ma trận khả nghịch.")

# 3. Tính ma trận nghịch đảo A^{-1}
A_inv = np.linalg.inv(A)
print("\nMa trận nghịch đảo A^{-1}")
print(np.round(A_inv, 2))

# 4. Tìm nghiệm x bằng công thức x = A^{-1}b
# Sử dụng toán tử @ để nhân ma trận
solution = A_inv @ b
print("\n Nghiệm của hệ phương trình (x, y, z)")
print(np.round(solution, 2))

# 5. Kiểm tra lại kết quả
check = A @ solution
print("\n Kiểm tra lại: A @ x")
print(np.round(check, 2))
print(f"Kết quả có khớp với vector b ban đầu không? {np.allclose(check, b)}")

# %% [markdown]
# # **Câu hỏi ôn tập về Pandas**

# %%
import pandas as pd

# %% [markdown]
# ## **Bài thực hành 7**

# %% [markdown]
# ### **Đề bài**
# Cho một Dictionary chứa dân số của một số thành phố ở Việt Nam (ước tính triệu người) như dưới đây:
#
# 1. Tạo một đối tượng pd.Series tên `city_pop` từ `population_dict` trên.
# 2. Sử dụng một danh sách chỉ số, hãy trích xuất và in ra dân số của "Hanoi" và "Danang".
# 3. Tạo một Series mới bằng cách nhân tất cả giá trị dân số trong `city_pop` với 1,000,000 để quy đổi về đơn vị người.

# %%
import pandas as pd

population_dict = {"Hanoi": 8.5, "HCMC": 9.3, "Danang": 1.2, "Haiphong": 2.1}

# %% [markdown]
# ### **Đáp án**

# %%
import pandas as pd
# 1. Tạo Series từ Dictionary
population_dict = {"Hanoi": 8.5, "HCMC": 9.3, "Danang": 1.2, "Haiphong": 2.1}
city_pop = pd.Series(population_dict)

print("Dân số các thành phố (triệu người)")
print(city_pop)

# 2. Trích xuất dữ liệu
hanoi_danang_pop = city_pop[["Hanoi", "Danang"]]
print("\n Dân số Hà Nội và Đà Nẵng")
print(hanoi_danang_pop)

# 3. Thực hiện phép toán vector hóa
city_pop_in_millions = city_pop * 1_000_000
print("\n Dân số các thành phố (đơn vị: người)")
print(city_pop_in_millions.astype(int))

# %% [markdown]
# ## **Bài thực hành 8**

# %% [markdown]
# ### **Đề bài**
# 1. Tạo một DataFrame tên sales_df từ Dictionary dưới đây, chứa dữ liệu bán hàng của nhân viên.
# 2. Thêm một cột mới tên là `thuong` (thưởng). Giá trị của cột này là True nếu `doanh_so` của nhân viên đó lớn hơn 100, và False nếu ngược lại.
# 3. Thêm một cột nữa tên là `tien_thuong`. Nếu nhân viên được thưởng, số tiền thưởng là 10% của `doanh_so`. Nếu không, tiền thưởng là 0.
#
# 4. Giả sử cột `khu_vuc` không còn cần thiết, hãy xóa cột này khỏi `sales_df`. In ra DataFrame cuối cùng.

# %%
import pandas as pd

sales_data = {
    "nhan_vien": ["An", "Binh", "Chi", "Dung"],
    "khu_vuc": ["Bắc", "Nam", "Trung", "Bắc"],
    "doanh_so": [120, 250, 180, 90]
}

# %% [markdown]
# ### **Đáp án**

# %%
import pandas as pd

# 1. Tạo DataFrame
sales_data = {
    "nhan_vien": ["An", "Binh", "Chi", "Dung"],
    "khu_vuc": ["Bắc", "Nam", "Trung", "Bắc"],
    "doanh_so": [120, 250, 180, 90]
}
sales_df = pd.DataFrame(sales_data)
print("DataFrame Bán hàng ban đầu")
print(sales_df)

# 2. Thêm cột "thuong" dựa trên điều kiện
sales_df["thuong"] = sales_df["doanh_so"] > 100
print("\nDataFrame sau khi thêm cột 'thuong'")
print(sales_df)

# 3. Thêm cột "tien_thuong"
# Sử dụng np.where(điều_kiện, giá_trị_nếu_đúng, giá_trị_nếu_sai)
sales_df["tien_thuong"] = np.where(sales_df["thuong"], sales_df["doanh_so"] * 0.1, 0)
print("\nDataFrame sau khi thêm cột 'tien_thuong'")
print(sales_df)

# 4. Xóa cột "khu_vuc"
del sales_df["khu_vuc"]
print("\n DataFrame cuối cùng sau khi xóa cột")
print(sales_df)

# %% [markdown]
# ## **Bài thực hành 9**

# %% [markdown]
# ### **Đề bài**
# 1. Tạo một DataFrame 4x4 từ mảng NumPy chứa các số từ 0 đến 15. Đặt tên chỉ số hàng là `["A", "B", "C", "D"]` và tên cột là `["W", "X", "Y", "Z"]`.
#
# 2. Sử dụng `.loc`, hãy chọn và in ra dữ liệu của các hàng `"A", "C"` và các cột `"W", "Y"`.
#
# 3. Sử dụng `.iloc`, hãy chọn và in ra dữ liệu của 2 hàng cuối cùng và 2 cột đầu tiên.
#
# 4. Sử dụng `.loc`, hãy lấy ra giá trị nằm ở hàng `"B"`, cột `"Z"`.

# %% [markdown]
# ### **Đáp án**

# %%
import pandas as pd
import numpy as np

# 1. Tạo DataFrame
df = pd.DataFrame(
    np.arange(16).reshape(4, 4),
    index=["A", "B", "C", "D"],
    columns=["W", "X", "Y", "Z"]
)
print("DataFrame gốc")
print(df)

# 2. Lựa chọn bằng .loc (theo nhãn)
subset_loc = df.loc[["A", "C"], ["W", "Y"]]
print("\n Dữ liệu từ .loc[['A', 'C'], ['W', 'Y']]")
print(subset_loc)

# 3. Lựa chọn bằng .iloc (theo vị trí số nguyên)
# 2 hàng cuối: vị trí 2, 3 (lát cắt 2:)
# 2 cột đầu: vị trí 0, 1 (lát cắt :2)
subset_iloc = df.iloc[2:, :2]
print("\n Dữ liệu từ .iloc[2:, :2]")
print(subset_iloc)

# 4. Lấy một giá trị đơn lẻ
single_value = df.loc["B", "Z"]
print(f"\n Giá trị tại hàng 'B', cột 'Z' là: {single_value}")

# %% [markdown]
# ## **Bài thực hành 10**

# %% [markdown]
# ### **Đề bài**
# Cho một Series `product_stock` chứa dữ liệu về số lượng tồn kho của một số sản phẩm như dưới đây.
#
# 1. Sử dụng phương thức reindex, hãy tạo một Series mới tên `full_stock` có chỉ số là tất cả các số nguyên từ 0 đến 5. In ra `full_stock`.
#
# 2. Tạo một Series khác tên `filled_stock` bằng cách `reindex` lại `product_stock` sử dụng tham số method="ffill" để điền các giá trị thiếu bằng giá trị hợp lệ gần nhất trước đó.

# %%
import pandas as pd

product_stock = pd.Series([10, 50, 30], index=[0, 3, 5])

# %% [markdown]
# ### **Đáp án**

# %%
import pandas as pd
import numpy as np

product_stock = pd.Series([10, 50, 30], index=[0, 3, 5])
print("Series ban đầu")
print(product_stock)

# 1. Reindex để tạo ra các chỉ số bị thiếu
full_stock = product_stock.reindex(np.arange(6))
print("\nSeries sau khi reindex")
print(full_stock)

# 2. Reindex và điền giá trị bằng 'ffill' (forward-fill)
filled_stock = product_stock.reindex(np.arange(6), method="ffill")
print("\nSeries sau khi reindex và điền giá trị")
print(filled_stock)

# %% [markdown]
# ## **Bài thực hành 11**

# %% [markdown]
# ### **Đề bài**
# 1. Tạo một DataFrame tên `student_scores` từ Dictionary cho dưới đây. Đặt chỉ số hàng là tên của sinh viên: `["Hùng", "Lan", "Minh", "An"]`
#
# 2. Sử dụng `sort_values`, hãy sắp xếp DataFrame theo thứ tự điểm `"Toan"` giảm dần
#
# 3. Sử dụng phương thức sum với tham số axis=1 để tính tổng điểm cho mỗi sinh viên
#
# 4. Sử dụng phương thức .describe() để hiển thị các thông tin thống kê tóm tắt (như trung bình, min, max, std...) cho điểm của từng môn học

# %%
import pandas as pd

scores_data = {
    "Toan": [7, 5, 9, 8],
    "Ly": [8, 9, 6, 7],
    "Hoa": [6, 8, 9, 5]
}

# %% [markdown]
# ### **Đáp án**

# %%
import pandas as pd
import pandas as pd

# 1. Tạo DataFrame
scores_data = {
    "Toan": [7, 5, 9, 8],
    "Ly": [8, 9, 6, 7],
    "Hoa": [6, 8, 9, 5]
}
student_scores = pd.DataFrame(scores_data, index=["Hùng", "Lan", "Minh", "An"])
print("Bảng điểm ban đầu")
print(student_scores)

# 2. Sắp xếp theo điểm Toán giảm dần
sorted_by_math = student_scores.sort_values(by="Toan", ascending=False)
print("\n Bảng điểm sắp xếp theo môn Toán")
print(sorted_by_math)

# 3. Tính tổng điểm mỗi sinh viên
student_scores["Tong_diem"] = student_scores.sum(axis=1)
print("\nBảng điểm với cột tổng điểm")
print(student_scores)

# 4. Thống kê mô tả
print("\n Thống kê mô tả điểm các môn")
print(student_scores[["Toan", "Ly", "Hoa"]].describe())

# %% [markdown]
# ## **Bài thực hành 12**

# %% [markdown]
# ### **Đề bài**
# File `transactions.csv` tải về [tại đây](https://drive.google.com/file/d/1Nty62dcwCcSbXWLK6vXUzUoU8s2Qy7j9/view?usp=sharing) hoặc chạy đoạn code sử dụng thư viện `gdown` ở dưới.
# 1. Đọc file `transactions.csv` vào một DataFrame có tên `df`.
#
# 2. Hiển thị 5 dòng đầu tiên của df bằng phương thức và kiểm tra các kiểu dữ liệu cũng như thông tin về giá trị thiếu trong DataFrame.
#
# 3. Trong cột `"SoLuong"`, có một giá trị bị thiếu. Hãy điền giá trị thiếu đó bằng số 1 (giả sử đơn hàng đó bán được 1 sản phẩm).
#
# 4. Tạo một cột mới tên là `ThanhTien` bằng cách nhân cột `DonGia` với cột `SoLuong`.
#
# 5. Sử dụng boolean indexing, lọc và hiển thị tất cả các giao dịch thuộc nhóm hàng `"Điện tử"`.

# %%
# Link file: https://drive.google.com/file/d/1Nty62dcwCcSbXWLK6vXUzUoU8s2Qy7j9/view?usp=sharing
# pip install gdown
# !gdown 1Nty62dcwCcSbXWLK6vXUzUoU8s2Qy7j9

# %% [markdown]
# ### **Đáp án**

# %%
import pandas as pd
import numpy as np

# 1. Đọc file CSV vào DataFrame
# Giả sử file transactions.csv nằm cùng thư mục với code
df = pd.read_csv("transactions.csv")

print("DataFrame sau khi đọc từ file CSV")
print(df)

# 2. Hiển thị thông tin cơ bản
print("\n 5 dòng đầu tiên của DataFrame")
print(df.head())

print("\nThông tin và kiểu dữ liệu của DataFrame")
df.info()

# 3. Điền giá trị thiếu trong cột "SoLuong"
# inplace=True để thay đổi trực tiếp trên DataFrame gốc
df["SoLuong"] = df["SoLuong"].fillna(1)
print("\nDataFrame sau khi điền giá trị thiếu")
print(df)


# 4. Tạo cột mới "ThanhTien"
df["ThanhTien"] = df["DonGia"] * df["SoLuong"]
print("\nDataFrame sau khi thêm cột 'ThanhTien'")
print(df)

# 5. Lọc các giao dịch thuộc nhóm hàng "Điện tử"
dien_tu_df = df[df["NhomHang"] == "Điện tử"]
print("\n Các giao dịch thuộc nhóm hàng Điện tử")
print(dien_tu_df)
